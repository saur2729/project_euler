# %%
import os
import sys
import glob
import math
import requests

from utils.math_helper import *

# %%
z = raw_data.replace(",,", ",").replace('"', "").split(",")

# %%
z[:10]
# Out:
# ['MARY',
#  'PATRICIA',
#  'LINDA',
#  'BARBARA',
#  'ELIZABETH',
#  'JENNIFER',
#  'MARIA',
#  'SUSAN',
#  'MARGARET',
#  'DOROTHY']

# %%
sorted(z).index("COLIN")
# Out:
# 937

# %%
find_factors_simple(12)
# Out:
# [1, 2, 3, 4, 6, 12]
